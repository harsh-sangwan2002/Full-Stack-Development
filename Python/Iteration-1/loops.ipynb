# %%
i = 1
n = 5
while(i<=n):
    print(i)
    i+=1

# %%
n = 5
while(n>0):
    print(n)
    n-=1

# %%
i = 1
n = 100
while(i<=n):
    if(i%2==0):
        print(i)
    i+=1

# %%
i = 2; n = 20; sum = 0
while(i<=n):
    sum+=i
    i+=2
print(sum)

# %%
n = 459
while(n>0):
    print(n%10)
    n//=10

# %%
# else will only run if the loop is successfully terminated
count = 1
while(count<=100):
    if(count==4):
        break
    print(count)
    count+=1
else:
    print("YAY")

# %%
n = 3
i = 2
while(i*i<=n):
    if(n%i==0):
        print("Not Prime")
        break
    i+=1
else:
    print("Prime")

# %%
count = 1
while(count <= 5):
    if(count == 3):
        continue
    print(count, end = ' ')
    count += 1

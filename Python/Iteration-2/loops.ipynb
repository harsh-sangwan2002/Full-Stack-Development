# %%
for i in range(1,101):
    print(i)

# %%
for _ in range(0,10):
    print('Hello')

# %%
for i in range(20):
    if(i%2==0):
        pass
    print(i)

# %%
n = 20
for i in range(2,n):
    if(n%2==0):
        print('Not Prime')
        break
else:
    print('Prime')

# %%
n = 5
for _ in range(n):
    for _ in range(n):
        print("*",end=' ')
    print()
# Out:
# * * * * *
# * * * * *
# * * * * *
# * * * * *
# * * * * *

# %%
for i in range(1,6):
    for j in range(i):
        print("*",end=' ')
    print()
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *

# %%
n = 5; nsp = n-1; nst = 1
for i in range(n):
    for j in range(nsp):
        print(' ',end=' ')
    for j in range(nst):
        print('*',end=' ')
    nsp -= 1
    nst += 1
    print()
# Out:
#         *
#       * *
#     * * *
#   * * * *
# * * * * *

# %%
n = 6; nsp = n//2; nst = 1
for i  in range(n):
    for j in range(nsp):
        print(' ',end=' ')
    for j in range(nst):
        print('*',end=' ')
    if(i<n//2):
        nsp-=1
        nst+=2
    else:
        nsp+=1
        nst-=2
    print()
# Out:
#       *
#     * * *
#   * * * * *
# * * * * * * *
#   * * * * *
#     * * *

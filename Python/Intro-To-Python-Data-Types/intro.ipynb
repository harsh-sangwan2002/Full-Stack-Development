# %%
print('Hello World');

# %%
print("10");

# %%
print("10 + 10");

# %%
print(10-2);

# %%
print(10*2);

# %%
Print(10*22);

# %%
print(type(23));

# %%
print(type("Hello"));

# %%
print(type('a'));

# %%
print(type(10.0));

# %%
print("""Hello
      World""");

# %%
print(type(True));

# %%
print(type(False));

# %%
Print(type(False));

# %%
# This is a single-line comment

# %%
"""
This is a multi-line comment
"""

# %%
a = 10;

# %%
print(a);

# %%
print(type(a));

# %%
pi = 3.14;
print(type(pi));

# %%
acb123_ = 10;

# %%
a = "1234"
b = int(a)
print(a);
print(b);
print(type(b));
# Out:
# 1234
# 1234
# <class 'int'>

# %%
a = "12";
b = float(a);
print(b);
print(type(b));
# Out:
# 12.0
# <class 'float'>

# %%
print(bool(""));
# Out:
# False

# %%
print(bool(0));
# Out:
# False

# %%
a = 123;
b = str(a);
print(b);
print(type(b));
# Out:
# 123
# <class 'str'>

# %%
a = 123.34;
b = str(a);
print(b);
print(type(b));
# Out:
# 123.34
# <class 'str'>

# %%
print(bool(-1));
# Out:
# True

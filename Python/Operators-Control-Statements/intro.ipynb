# %%
print("Rahul", "Rohit", "Emma Watson", sep=" ")
print("Yash","KGF")
# Out:
# Rahul Rohit Emma Watson
# Yash KGF

# %%
a = 5
b = 6
print(a+b)
# Out:
# 11

# %%
print(2+True)
# Out:
# 3

# %%
print(3+False)
# Out:
# 3

# %%
print('1'+'1')
print(type(True))
# Out:
# 11
# <class 'bool'>

# %%
# Cannot add string and integer
# Not allowed -> int/float/bool + string
print('1'+1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 print('1'+1)
#
# TypeError: can only concatenate str (not "int") to str

# %%
print(2*3)
# Out:
# 6

# %%
# In string * means repetition
print('Harsh Sangwan\n'*10)
# Out:
# Harsh Sangwan
# Harsh Sangwan
# Harsh Sangwan
# Harsh Sangwan
# Harsh Sangwan
# Harsh Sangwan
# Harsh Sangwan
# Harsh Sangwan
# Harsh Sangwan
# Harsh Sangwan
